# %% [markdown]
# # Observing Mechanistic Model Results

# %% [markdown]
# ### Load packages and data

# %%
import altair as alt
import pandas as pd

# Mechanistic Model Results
mm_results = pd.read_csv('../sample_datasets/mol_res_scan_results_10_sourceQ.csv')
mm_results = mm_results.sample(5000)
mm_results = mm_results.reset_index()

# %% [markdown]
# ### Observe purity vs. yield

# %%
alt.Chart(mm_results).mark_point().encode(
    x='yield',
    y='purity')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Optimized conditions when purity and yield approach 1.0

# %% [markdown]
# ### Set threshhold for each purity and yield

# %%
purity_thresh = 0.9
yield_thresh = 0.9

# %% [markdown]
# ### List results that exceed the threshholds set

# %%
# Initialize results dataframe
column_names = list(mm_results.columns.values)
optimized_runs = pd.DataFrame(columns=column_names)

# Add optimized runs to optimized array from results array
for i in range(5000):
    if mm_results['yield'].iloc[i] >= yield_thresh:
        if mm_results['purity'].iloc[i] >= purity_thresh:
            optimized_runs = optimized_runs.append(mm_results.loc[i])
            
# View optimized runs results as Pandas DataFrame 
optimized_runs
# Out:
#         index  Unnamed: 0  cut 1  cut 2     yield    purity  c_s         v  \
# 2110  21026.0     21026.0    3.0   24.0  0.901769  0.926429  0.2  0.522124
# 2627  14525.0     14525.0    0.0   18.0  1.071368  0.908745  0.2  0.701980
# 3009  21028.0     21028.0    3.0   30.0  0.930512  0.924201  0.2  0.522124
# 4646  14523.0     14523.0    0.0   12.0  1.011239  0.907342  0.2  0.701980
#
#       mol1_D_L  mol1_k_ov  ...  mol1_z_p  mol1_n  mol1_K_s  mol2_D_L  \
# 2110     0.059      0.542  ...  3.738871     0.0       0.0     0.059
# 2627     0.059      0.542  ...  3.497973     0.0       0.0     0.059
# 3009     0.059      0.542  ...  3.738871     0.0       0.0     0.059
# 4646     0.059      0.542  ...  3.497973     0.0       0.0     0.059
#
#       mol2_k_ov  mol2_q_max   mol2_K_eq  mol2_z_p  mol2_n  mol2_K_s
# 2110      0.542   38.035977  873.805219  2.004343     0.0       0.0
# 2627      0.542    1.080838  798.351471  3.800341     0.0       0.0
# 3009      0.542   38.035977  873.805219  2.004343     0.0       0.0
# 4646      0.542    1.080838  798.351471  3.800341     0.0       0.0
#
# [4 rows x 22 columns]
